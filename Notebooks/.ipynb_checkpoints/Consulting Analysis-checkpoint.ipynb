# %%
import pandas as pd

df_contracts = pd.read_csv('../data/contracts.csv')

df_customers = pd.read_csv('../data/customers.csv')

df_customers.rename(columns={'id':'customer_id'}, inplace=True)

df_customers.set_index('customer_id', inplace=True)

df_contracts = df_contracts.set_index('customer_id')

df = df_contracts.join(df_customers, how='left')
df.head(25)
# Out:
#              contract_id contract_start  contract_term     deposit  \
# customer_id
# 1                     41      5/31/2019             24  $86,000.00
# 1                    358      6/18/2019             13  $74,000.00
# 1                    400      8/11/2019             19  $38,000.00
# 1                    424      3/13/2019             15  $77,000.00
# 1                    438     10/16/2019             22  $39,000.00
# 1                    657      8/27/2019             24  $67,000.00
# 1                    848     11/15/2019             11  $34,000.00
# 2                    308      3/28/2019             24  $14,000.00
# 2                    416     12/25/2019             18  $63,000.00
# 2                    645      9/20/2019              3  $34,000.00
# 2                    754     11/15/2019             12  $76,000.00
# 2                    954      1/31/2019             14  $15,000.00
# 3                    361      8/11/2019              1  $49,000.00
# ...

# %%
#Pivot and Sort
df.groupby('state').agg({'contract_id':'count', 'company':pd.Series.nunique}).sort_values('company', ascending=False)
# Out:
#        contract_id  company
# state
# TX             104       21
# CA              88       17
# FL              70       15
# NY              43       11
# WA              54        9
# DC              32        8
# PA              29        7
# KS              43        7
# VA              35        7
# OH              33        6
# LA              33        6
# WI              24        6
# CO              34        6
# OR              22        5
# OK              34        5
# AZ              22        5
# MO              26        5
# GA              15        4
# MD              18        4
# MI              20        4
# IL              23        4
# TN              16        4
# NC              25        4
# ID              18        3
# NE              22        3
# MN              18        3
# DE              14        3
# IN              11        3
# NV               9        2
# CT              11        2
# SC               5        1
# AK               8        1
# ...

# %%
#filter
list(df.loc[df['state'] == 'FL', 'company'].unique())
# Out:
# ['Skyba',
#  'Blogtags',
#  'Devpoint',
#  'Flipbug',
#  'Jaxworks',
#  'Thoughtstorm',
#  'Realbuzz',
#  'Dablist',
#  'Fiveclub',
#  'Thoughtblab',
#  'Eire',
#  'Mita',
#  'Realmix',
#  'Livefish',
#  'Pixope']

# %%
import re

for each in ['deposit', 'monthly_amt']:
    df.loc[:, each] = pd.to_numeric(
        [re.sub('[^0-9]','', str(s)) for s in df[each]]
    )

df
# Out:
#              contract_id contract_start  contract_term  deposit  monthly_amt  \
# customer_id
# 1                     41      5/31/2019             24  8600000      1120000
# 1                    358      6/18/2019             13  7400000      1900000
# 1                    400      8/11/2019             19  3800000       880000
# 1                    424      3/13/2019             15  7700000      1430000
# 1                    438     10/16/2019             22  3900000      2000000
# ...                  ...            ...            ...      ...          ...
# 200                  284     12/28/2019             17  7800000      1760000
# 200                  540      4/17/2019              3  6500000       980000
# 200                  630      11/1/2019             12  8500000      1260000
# 200                  862      10/2/2019             21  4800000       650000
# 200                  973      8/21/2019              1  4700000      1230000
#
# ...

# %%
df['contract_amount'] = df['deposit'] + (df['contract_term'] * df['monthly_amt'])
df.head()
# Out:
#              contract_id contract_start  contract_term  deposit  monthly_amt  \
# customer_id
# 1                     41      5/31/2019             24  8600000      1120000
# 1                    358      6/18/2019             13  7400000      1900000
# 1                    400      8/11/2019             19  3800000       880000
# 1                    424      3/13/2019             15  7700000      1430000
# 1                    438     10/16/2019             22  3900000      2000000
#
#                company         sector                       industry  \
# customer_id
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
# 1            Bubblebox  Capital Goods  Military/Government/Technical
#
# ...

# %%
print('Conclusion')
#I don't remember how to make it a header.

# %%
a = 'After reviewing the analysis, it was clear to see that Texas has the most customers. As for contracts signed and unique companies, they do majority of their business companies in California, Texas, and Florida. Overall, Texas would be the best option because there are more opportunities with the businesses they do.'
print(a)
b = 'As for the location of headquarters, California is the best option because of the endless possible profit chances.'
print(b)
c = 'Because California is the best opportunity, headquarters should be placed there. It is hands-down the best location considering signed contracts and companies.'
print(c)
# Out:
# After reviewing the analysis, it was clear to see that Texas has the most customers. As for contracts signed and unique companies, they do majority of their business companies in California, Texas, and Florida. Overall, Texas would be the best option because there are more opportunities with the businesses they do.
# As for the location of headquarters, California is the best option because of the endless possible profit chances.
# Because California is the best opportunity, headquarters should be placed there. It is hands-down the best location considering signed contracts and companies.
